# %%
print("a)
# Out:
#   Cell In[1], line 1
#     print("a)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("a00")
# Out:
# a00

# %%
print("终于成功了！！！哭死！！！")
# Out:
# 终于成功了！！！哭死！！！

# %% [markdown]
# # 太兴奋了
# ## 终于能进行下一步了
# ### 我就知道我可以的！！！
